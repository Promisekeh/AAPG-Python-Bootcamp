# %%
#import pandas in jupyter environment:
import pandas

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
df = pd.read_csv("C:/Users/judee/Downloads/AAPG project/water_quality_dataset_100k.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        pH      Iron   Nitrate    Chloride           Lead  \
# 0           0  8.332988  0.000083  8.605777  122.799772   3.713298e-52
# 1           1  6.917863  0.000081  3.734167  227.029851   7.849262e-94
# 2           2  5.443762  0.020106  3.816994  230.995630   5.286616e-76
# 3           3  7.955339  0.143988  8.224944  178.129940  3.997118e-176
# 4           4  8.091909  0.002167  9.925788  186.540872  4.171069e-132
#
#        Zinc           Color  Turbidity  Fluoride  ...  Chlorine     Manganese  \
# 0  3.434827       Colorless   0.022683  0.607283  ...  3.708178  2.269945e-15
# 1  1.245317    Faint Yellow   0.019007  0.622874  ...  3.292038  8.024076e-07
# 2  0.528280    Light Yellow   0.319956  0.423423  ...  3.560224  7.007989e-02
# 3  4.027879  Near Colorless   0.166319  0.208454  ...  3.516907  2.468295e-02
# 4  3.807511    Light Yellow   0.004867  0.222912  ...  3.177849  3.296139e-03
#
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0        pH      Iron   Nitrate    Chloride           Lead  \
# 99996        99996  8.818809  0.000075  5.491966         NaN   1.018468e-16
# 99997        99997  7.277367  0.000022  2.878326  126.880370   1.965436e-22
# 99998        99998  7.000954  0.012017  4.157934  165.559327  5.501361e-126
# 99999        99999  8.374296  0.134012  2.631553  148.166082   3.845744e-40
# 100000      100000  7.154356  0.092041  5.656341  212.623606   3.102165e-72
#
#             Zinc         Color  Turbidity  Fluoride  ...  Chlorine  Manganese  \
# 99996   0.054606  Light Yellow   0.618404  1.517286  ...  2.479101   0.006608
# 99997   3.632629     Colorless   0.291402  0.228949  ...  3.315341   0.001116
# 99998   2.162606  Faint Yellow   0.055013  0.275803  ...  3.457473   0.010697
# 99999   0.251668     Colorless   0.406297  0.458973  ...  2.603017   0.000242
# 100000  2.462944     Colorless   0.000355  0.962474  ...  2.907079   0.023063
#
# ...

# %% [markdown]
# ## DATA CLEANING AND PROCESSING

# %%
df.isnull().sum().sum()
# Out:
# 39672

# %%
df5 = df.fillna({'Source': 'unknown',
                 'Month':  'unknown',
                 'Color': 'Odor'})
df5
# Out:
#         Unnamed: 0        pH      Iron   Nitrate    Chloride           Lead  \
# 0                0  8.332988  0.000083  8.605777  122.799772   3.713298e-52
# 1                1  6.917863  0.000081  3.734167  227.029851   7.849262e-94
# 2                2  5.443762  0.020106  3.816994  230.995630   5.286616e-76
# 3                3  7.955339  0.143988  8.224944  178.129940  3.997118e-176
# 4                4  8.091909  0.002167  9.925788  186.540872  4.171069e-132
# ...            ...       ...       ...       ...         ...            ...
# 99996        99996  8.818809  0.000075  5.491966         NaN   1.018468e-16
# 99997        99997  7.277367  0.000022  2.878326  126.880370   1.965436e-22
# 99998        99998  7.000954  0.012017  4.157934  165.559327  5.501361e-126
# 99999        99999  8.374296  0.134012  2.631553  148.166082   3.845744e-40
# 100000      100000  7.154356  0.092041  5.656341  212.623606   3.102165e-72
#
# ...

# %%
df6 = df5.fillna(value=df['Chloride'].mean())
df6
# Out:
#         Unnamed: 0        pH      Iron   Nitrate    Chloride           Lead  \
# 0                0  8.332988  0.000083  8.605777  122.799772   3.713298e-52
# 1                1  6.917863  0.000081  3.734167  227.029851   7.849262e-94
# 2                2  5.443762  0.020106  3.816994  230.995630   5.286616e-76
# 3                3  7.955339  0.143988  8.224944  178.129940  3.997118e-176
# 4                4  8.091909  0.002167  9.925788  186.540872  4.171069e-132
# ...            ...       ...       ...       ...         ...            ...
# 99996        99996  8.818809  0.000075  5.491966  174.085913   1.018468e-16
# 99997        99997  7.277367  0.000022  2.878326  126.880370   1.965436e-22
# 99998        99998  7.000954  0.012017  4.157934  165.559327  5.501361e-126
# 99999        99999  8.374296  0.134012  2.631553  148.166082   3.845744e-40
# 100000      100000  7.154356  0.092041  5.656341  212.623606   3.102165e-72
#
# ...

# %%
df7 = df5.fillna(value=df['Water Temperature'].mean())
df7
# Out:
#         Unnamed: 0        pH      Iron   Nitrate    Chloride           Lead  \
# 0                0  8.332988  0.000083  8.605777  122.799772   3.713298e-52
# 1                1  6.917863  0.000081  3.734167  227.029851   7.849262e-94
# 2                2  5.443762  0.020106  3.816994  230.995630   5.286616e-76
# 3                3  7.955339  0.143988  8.224944  178.129940  3.997118e-176
# 4                4  8.091909  0.002167  9.925788  186.540872  4.171069e-132
# ...            ...       ...       ...       ...         ...            ...
# 99996        99996  8.818809  0.000075  5.491966   19.205925   1.018468e-16
# 99997        99997  7.277367  0.000022  2.878326  126.880370   1.965436e-22
# 99998        99998  7.000954  0.012017  4.157934  165.559327  5.501361e-126
# 99999        99999  8.374296  0.134012  2.631553  148.166082   3.845744e-40
# 100000      100000  7.154356  0.092041  5.656341  212.623606   3.102165e-72
#
# ...

# %%
df7 = df5.fillna(value=df['pH'].mean())
df7
# Out:
#         Unnamed: 0        pH      Iron   Nitrate    Chloride           Lead  \
# 0                0  8.332988  0.000083  8.605777  122.799772   3.713298e-52
# 1                1  6.917863  0.000081  3.734167  227.029851   7.849262e-94
# 2                2  5.443762  0.020106  3.816994  230.995630   5.286616e-76
# 3                3  7.955339  0.143988  8.224944  178.129940  3.997118e-176
# 4                4  8.091909  0.002167  9.925788  186.540872  4.171069e-132
# ...            ...       ...       ...       ...         ...            ...
# 99996        99996  8.818809  0.000075  5.491966    7.465820   1.018468e-16
# 99997        99997  7.277367  0.000022  2.878326  126.880370   1.965436e-22
# 99998        99998  7.000954  0.012017  4.157934  165.559327  5.501361e-126
# 99999        99999  8.374296  0.134012  2.631553  148.166082   3.845744e-40
# 100000      100000  7.154356  0.092041  5.656341  212.623606   3.102165e-72
#
# ...

# %%
df7.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Outputing Dataframe

# %%
df7.to_csv('data.csv', index=False)
df7.to_csv('data.txt', sep='\t', index=False)
df7.to_json('data.json', orient='records', lines=True)

# %%
X = df7.drop('pH', axis=1)
y = df7['pH']

# %%
y
# Out:
# 0         8.332988
# 1         6.917863
# 2         5.443762
# 3         7.955339
# 4         8.091909
#             ...
# 99996     8.818809
# 99997     7.277367
# 99998     7.000954
# 99999     8.374296
# 100000    7.154356
# Name: pH, Length: 100001, dtype: float64

# %%
X
# Out:
#         Unnamed: 0      Iron   Nitrate    Chloride           Lead      Zinc  \
# 0                0  0.000083  8.605777  122.799772   3.713298e-52  3.434827
# 1                1  0.000081  3.734167  227.029851   7.849262e-94  1.245317
# 2                2  0.020106  3.816994  230.995630   5.286616e-76  0.528280
# 3                3  0.143988  8.224944  178.129940  3.997118e-176  4.027879
# 4                4  0.002167  9.925788  186.540872  4.171069e-132  3.807511
# ...            ...       ...       ...         ...            ...       ...
# 99996        99996  0.000075  5.491966    7.465820   1.018468e-16  0.054606
# 99997        99997  0.000022  2.878326  126.880370   1.965436e-22  3.632629
# 99998        99998  0.012017  4.157934  165.559327  5.501361e-126  2.162606
# 99999        99999  0.134012  2.631553  148.166082   3.845744e-40  0.251668
# 100000      100000  0.092041  5.656341  212.623606   3.102165e-72  2.462944
#
# ...

# %%
np.random.random((3, 2))
# Out:
# array([[0.54340494, 0.27836939],
#        [0.42451759, 0.84477613],
#        [0.00471886, 0.12156912]])

# %%
np.random.seed(5)
np.random.random((3, 2))
# Out:
# array([[0.22199317, 0.87073231],
#        [0.20671916, 0.91861091],
#        [0.48841119, 0.61174386]])

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
one_hot = OneHotEncoder()

# %%
pd.DataFrame(one_hot.fit_transform(X))
# Out:
#                                                         0
# 0         (0, 0)\t1.0\n  (0, 134218)\t1.0\n  (0, 28515...
# 1         (0, 1)\t1.0\n  (0, 134053)\t1.0\n  (0, 22141...
# 2         (0, 2)\t1.0\n  (0, 168858)\t1.0\n  (0, 22270...
# 3         (0, 3)\t1.0\n  (0, 188191)\t1.0\n  (0, 28193...
# 4         (0, 4)\t1.0\n  (0, 151833)\t1.0\n  (0, 29394...
# ...                                                   ...
# 99996     (0, 99996)\t1.0\n  (0, 133763)\t1.0\n  (0, 2...
# 99997     (0, 99997)\t1.0\n  (0, 128715)\t1.0\n  (0, 2...
# 99998     (0, 99998)\t1.0\n  (0, 164493)\t1.0\n  (0, 2...
# 99999     (0, 99999)\t1.0\n  (0, 187415)\t1.0\n  (0, 2...
# 100000    (0, 100000)\t1.0\n  (0, 183463)\t1.0\n  (0, ...
#
# [100001 rows x 1 columns]

# %% [markdown]
# ## STANDARDIZATION

# %%
def logistic(x):
    return 1.0/(1+np.exp(-x))

# %%
x = np.linspace(-3, 3,9999)
y = logistic(x)

# %%
plt.plot(x,y)

plt.show()

# %%
from sklearn.datasets import load_iris

# %%
d = load_iris()

# %%
X = d['data']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(X)
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### Summary Analysis

# %%
df7.describe()
# Out:
#           Unnamed: 0             pH          Iron        Nitrate  \
# count  100001.000000  100001.000000  1.000010e+05  100001.000000
# mean    50000.000000       7.465820  1.193689e-01       5.807926
# std     28867.946472       0.695941  6.734633e-01       2.630192
# min         0.000000       2.433522  7.448581e-40       0.480498
# 25%     25000.000000       6.986572  7.164208e-06       3.920746
# 50%     50000.000000       7.465820  1.638033e-03       5.499675
# 75%     75000.000000       7.953027  3.935422e-02       7.454217
# max    100000.000000      12.040008  1.124382e+01      48.337580
#
#             Chloride           Lead           Zinc     Turbidity  \
# count  100001.000000   1.000010e+05  100001.000000  1.000010e+05
# mean      169.175668   3.402069e-02       1.610678  4.271005e-01
# std        61.800970   4.989455e-01       1.655439  8.903069e-01
# min         7.465820   0.000000e+00       0.000005  8.022392e-13
# ...

# %%
df7.shape
# Out:
# (100001, 24)

# %% [markdown]
# ## HISTOGRAM OF pH

# %%
df7['pH'].plot( kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## HISTOGRAM OF Iron

# %%
df7['Iron'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## HISTOGRAM OF Nitrate

# %%
df7['Nitrate'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## HISTOGRAM OF Chloride

# %%
df7['Chloride'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## BOX PLOTS

# %%
sns.boxplot(y='pH', data=df7, width=-0.5)
plt.title('Box Plot')
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(data=df7, x="pH", y="Chloride")
plt.title('pH vs Chloride')
plt.show()

# %%
sns.scatterplot(data=df7, x="pH", y="Nitrate")
plt.title('pH vs Nitrate')
plt.show()

# %% [markdown]
# ## Line Plot

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 8,6
plt.plot(df7.Nitrate)

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 8,6
plt.plot(df7.Chloride)

# %% [markdown]
# ## Corellation Matrix and Heatmap

# %%
corr_matrix = df7.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[427], line 1
# ----> 1 corr_matrix = df7.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
corr_matrix["Nitrate"]

# %% [markdown]
# ## Count Plot

# %%
df7.Source.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Source'>

# %%
df7.Month.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
df7.Color.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Color'>

# %% [markdown]
# ## TREND ANALYSIS

# %%
plt.figuresize=((20, 20))
plt.plot(df7['Month'], df7['Source'], label='Source')
plt.title('Time Series Analysis')
plt.show()

# %% [markdown]
# ## MODEL BUILDING

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model
# Out:
# RandomForestClassifier()

# %%
X = df7.drop('pH', axis=1)
y = df7['pH']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=5)

# %%
x_train
# Out:
#        Unnamed: 0          Iron    Nitrate    Chloride           Lead  \
# 72456       72456  3.087572e-03   6.450872  567.850272  2.069432e-250
# 10514       10514  2.889939e-04  21.427782  312.549442   4.648365e-52
# 78581       78581  6.736204e-04   5.061445  113.065187  2.207006e-191
# 95699       95699  3.963581e-05   6.531758  188.925018  6.443132e-124
# 11276       11276  5.863529e-18   6.823104  100.082437   8.464773e-32
# ...           ...           ...        ...         ...            ...
# 59465       59465  8.916333e-04   3.857150  157.253580  7.174834e-118
# 5520         5520  1.086210e-06   4.055313  179.073802   2.216142e-41
# 20463       20463  1.910333e-04   8.944702  148.474066   7.434500e-57
# 18638       18638  2.404528e-02   1.546427  160.036688   4.789138e-06
# 35683       35683  1.357862e-01   4.002206  239.149712   5.108612e-27
#
#            Zinc           Color  Turbidity  Fluoride    Copper  ...  Chlorine  \
# ...

# %%
y_train
# Out:
# 72456    9.066818
# 10514    6.758360
# 78581    7.465820
# 95699    7.892902
# 11276    7.938774
#            ...
# 59465    7.813891
# 5520     6.850830
# 20463    5.728708
# 18638    6.856757
# 35683    7.457419
# Name: pH, Length: 70000, dtype: float64

# %%
x_test
# Out:
#        Unnamed: 0      Iron   Nitrate    Chloride           Lead      Zinc  \
# 47921       47921  0.173533  4.194931    7.465820   6.654739e-14  1.360253
# 66726       66726  7.465820  3.720679  187.353952  1.793427e-178  7.465820
# 27200       27200  0.007031  6.286235  132.753590   1.629987e-69  0.345071
# 60972       60972  0.239447  3.293179  126.885688  3.222490e-311  1.562546
# 10238       10238  0.029842  9.921127  128.395133   5.341208e-60  1.096927
# ...           ...       ...       ...         ...            ...       ...
# 19626       19626  0.001886  5.563895  119.430541  7.507521e-282  2.086343
# 89533       89533  0.000003  6.972850  237.461168   0.000000e+00  2.244520
# 61856       61856  0.012529  2.774300  226.877621  8.199062e-125  4.380392
# 85925       85925  0.000099  7.760458  130.362891  2.113586e-169  2.889841
# 59671       59671  0.000190  4.284694  248.805522   1.850577e-52  1.219832
#
# ...

# %%
y_test
# Out:
# 47921    7.318957
# 66726    6.581876
# 27200    6.624220
# 60972    8.257274
# 10238    8.093765
#            ...
# 19626    7.872819
# 89533    6.991960
# 61856    7.622626
# 85925    8.907034
# 59671    6.992646
# Name: pH, Length: 30001, dtype: float64

# %%
np.random.seed(100)
for est in range(10, 300, 10):
    model = RandomForestClassifier(n_estimators=est)
    
    model.fit(y_train, y_test)
    print(f"model accuracy on test set: {est, model.score(x_test, y_test)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[470], line 5
#       2 for est in range(10, 300, 10):
#       3     model = RandomForestClassifier(n_estimators=est)
# ----> 5     model.fit(y_train, y_test)
#       6     print(f"model accuracy on test set: {est, model.score(x_test, y_test)}")
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:345, in BaseForest.fit(self, X, y, sample_weight)
#     343 if issparse(y):
#     344     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345 X, y = self._validate_data(
#     346     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347 )
#     348 if sample_weight is not None:
#     349     sample_weight = _check_sample_weight(sample_weight, X)
#
# ...

# %%
y_pred = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[487], line 1
# ----> 1 y_pred = model.predict(x_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:820, in ForestClassifier.predict(self, X)
#     799 def predict(self, X):
#     800     """
#     801     Predict class for X.
#     802
#    (...)
#     818         The predicted classes.
#     819     """
# --> 820     proba = self.predict_proba(X)
#     822     if self.n_outputs_ == 1:
#     823         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:860, in ForestClassifier.predict_proba(self, X)
#     838 def predict_proba(self, X):
#     839     """
#     840     Predict class probabilities for X.
#     841
#    (...)
#     858         classes corresponds to that in the attribute :term:`classes_`.
#     859     """
# ...

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
np.random.seed(100)
lr.fit(y_train, y_test)
lr.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[476], line 4
#       2 lr = LogisticRegression()
#       3 np.random.seed(100)
# ----> 4 lr.fit(y_train, y_test)
#       5 lr.score(x_test, y_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1196, in LogisticRegression.fit(self, X, y, sample_weight)
#    1193 else:
#    1194     _dtype = [np.float64, np.float32]
# -> 1196 X, y = self._validate_data(
#    1197     X,
#    1198     y,
#    1199     accept_sparse="csr",
#    1200     dtype=_dtype,
#    1201     order="C",
#    1202     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1203 )
#    1204 check_classification_targets(y)
#    1205 self.classes_ = np.unique(y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:584, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %% [markdown]
# ## Evaluating the Model

# %%
from sklearn.metrics import classification_report , confusion_matrix, accuracy_score

# %%
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[483], line 1
# ----> 1 print(classification_report(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined
